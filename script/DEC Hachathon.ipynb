# %%
import pandas as pd
import requests
import json

# %%
#API Key and Endpoint
API_KEY = "rnEayzudCbBTx29MZUeVD05Ybye515XULi6RTUBU"
BASE_URL = "https://api.data.gov/ed/collegescorecard/v1/schools"

#API parameters
params = {
    "api_key": API_KEY,
    "fields": "id,school.name,school.city,school.state,latest.admissions.admission_rate.overall,latest.cost.tuition.in_state,latest.cost.tuition.out_of_state,latest.earnings.10_yrs_after_entry.median",
    "per_page": 100,  
    "page": 0 
}

# %%
response= requests.get(BASE_URL, params=params)

# %%
data=response.json()

# %%
print(data)
# Out:
# {'metadata': {'page': 0, 'total': 6484, 'per_page': 100}, 'results': [{'latest.admissions.admission_rate.overall': 0.684, 'latest.cost.tuition.in_state': 10024, 'latest.cost.tuition.out_of_state': 18634, 'latest.earnings.10_yrs_after_entry.median': 40628, 'school.name': 'Alabama A & M University', 'school.city': 'Normal', 'school.state': 'AL', 'id': 100654}, {'latest.admissions.admission_rate.overall': 0.8668, 'latest.cost.tuition.in_state': 8832, 'latest.cost.tuition.out_of_state': 21216, 'latest.earnings.10_yrs_after_entry.median': 54501, 'school.name': 'University of Alabama at Birmingham', 'school.city': 'Birmingham', 'school.state': 'AL', 'id': 100663}, {'latest.admissions.admission_rate.overall': None, 'latest.cost.tuition.in_state': None, 'latest.cost.tuition.out_of_state': None, 'latest.earnings.10_yrs_after_entry.median': 37621, 'school.name': 'Amridge University', 'school.city': 'Montgomery', 'school.state': 'AL', 'id': 100690}, {'latest.admissions.admission_rate.overall': 
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
